# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
cell_df = pd.read_csv('cell_samples.csv')
cell_df.head(5)
# Out:
#         ID  Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  \
# 0  1000025      5         1          1        1            2       1
# 1  1002945      5         4          4        5            7      10
# 2  1015425      3         1          1        1            2       2
# 3  1016277      6         8          8        1            3       4
# 4  1017023      4         1          1        3            2       1
#
#    BlandChrom  NormNucl  Mit  Class
# 0           3         1    1      2
# 1           3         2    1      2
# 2           3         1    1      2
# 3           3         7    1      2
# 4           3         1    1      2

# %%
cell_df.isnull().sum()
# Out:
# ID             0
# Clump          0
# UnifSize       0
# UnifShape      0
# MargAdh        0
# SingEpiSize    0
# BareNuc        0
# BlandChrom     0
# NormNucl       0
# Mit            0
# Class          0
# dtype: int64

# %%
cell_df.duplicated().sum()
cell_df = cell_df.drop_duplicates()
cell_df.duplicated().sum()
# Out:
# 0

# %%
ax = cell_df[cell_df['Class'] == 4][0:50].plot(kind='scatter', x='Clump', y='UnifSize', color='DarkBlue', label='malignant');
cell_df[cell_df['Class'] == 2][0:50].plot(kind='scatter', x='Clump', y='UnifSize', color='Yellow', label='benign', ax=ax);
plt.show()

# %%
ax = cell_df[cell_df['Class'] == 4].plot(kind='scatter', x='Clump', y='UnifSize', color='DarkBlue', label='malignant');
cell_df[cell_df['Class'] == 2].plot(kind='scatter', x='Clump', y='UnifSize', color='Yellow', label='benign', ax=ax);
plt.show()

# %%
cell_df.columns

ax = cell_df[cell_df['Class']==4].plot(kind='scatter', x='Clump', y='UnifSize', color ='pink')
cell_df[cell_df['Class']==2].plot(kind='scatter', x='Clump', y='UnifSize', color ='blue', ax=ax)
plt.show()
